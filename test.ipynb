# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_id = "utter-project/EuroLLM-9B"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id)

text = "English: Are there no legal and administrative restrictions on the functioning of LGBTI organisations or publications?. Albanian:"

inputs = tokenizer(text, return_tensors="pt")
outputs = model.generate(**inputs, max_new_tokens=500)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Loading weights: 100%|██████████| 381/381 [00:00<00:00, 3995.93it/s]
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# English: Are there no legal and administrative restrictions on the functioning of LGBTI organisations or publications?. Albanian: Italian: Non vi sono restrizioni legali e amministrative sul funzionamento delle organizzazioni o delle pubblicazioni LGBTI?

# %%
# pip install 'transformers>=4.39.1'
from transformers import AutoTokenizer, AutoModelForCausalLM

model_id = "CohereLabs/c4ai-command-r-v01"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id)

msg = 'Translate the text between <text> and </text> into Albanian. Return ONLY the translation.\n            <text>Are there no legal and administrative restrictions on the functioning of LGBTI organisations or publications?</text>'
# Format message with the command-r chat template
messages = [{"role": "user", "content": msg}]
input_ids = tokenizer.apply_chat_template(messages, tokenize=True, add_generation_prompt=True, return_tensors="pt")
## <BOS_TOKEN><|START_OF_TURN_TOKEN|><|USER_TOKEN|>Hello, how are you?<|END_OF_TURN_TOKEN|><|START_OF_TURN_TOKEN|><|CHATBOT_TOKEN|>

gen_tokens = model.generate(
    input_ids, 
    max_new_tokens=500, 
    do_sample=True
    )

gen_text = tokenizer.decode(gen_tokens[0])
print(gen_text)
# Out:
# Loading weights: 100%|██████████| 322/322 [00:00<00:00, 3456.58it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/proj/RainbowMeter/.venv/lib64/python3.12/site-packages/transformers/tokenization_utils_base.py:275, in BatchEncoding.__getattr__(self, item)
#     274 try:
# --> 275     return self.data[item]
#     276 except KeyError:
#
# KeyError: 'shape'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 14
#      10 messages = [{"role": "user", "content": msg}]
#      11 input_ids = tokenizer.apply_chat_template(messages, tokenize=True, add_generation_prompt=True, return_tensors="pt")
#      12 ## <BOS_TOKEN><|START_OF_TURN_TOKEN|><|USER_TOKEN|>Hello, how are you?<|END_OF_TURN_TOKEN|><|START_OF_TURN_TOKEN|><|CHATBOT_TOKEN|>
#      13
# ---> 14 gen_tokens = model.generate(
#      15     input_ids,
#      16     max_new_tokens=500,
#      17     do_sample=True
#
# File ~/proj/RainbowMeter/.venv/lib64/python3.12/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/proj/RainbowMeter/.venv/lib64/python3.12/site-packages/transformers/generation/utils.py:2390, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, custom_generate, **kwargs)
#    2388 if "inputs_tensor" in inspect.signature(decoding_method).parameters.keys():
#    2389     generation_mode_kwargs["inputs_tensor"] = inputs_tensor
# -> 2390 batch_size = inputs_tensor.shape[0]
#    2392 device = inputs_tensor.device
#    2393 self._prepare_special_tokens(generation_config, kwargs_has_attention_mask, device=device)
#
# File ~/proj/RainbowMeter/.venv/lib64/python3.12/site-packages/transformers/tokenization_utils_base.py:277, in BatchEncoding.__getattr__(self, item)
#     275     return self.data[item]
#     276 except KeyError:
# --> 277     raise AttributeError
#
# AttributeError:

# %%
# pip install 'transformers>=4.39.1'
from transformers import AutoTokenizer, AutoModelForCausalLM
import re

def extract_model_answer(text):
    # Split on the chatbot marker
    parts = text.split("<|CHATBOT_TOKEN|>")
    
    if len(parts) < 2:
        return text.strip()  # fallback if format is unexpected
    
    # Take everything after the chatbot token
    answer = parts[-1]
    
    # Remove any ending special tokens
    answer = re.sub(r"<\|.*?\|>", "", answer)
    
    return answer.strip()

model_id = "CohereLabs/c4ai-command-r-v01"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id)

msg = 'Translate the text between <text> and </text> into Albanian. Return ONLY the translation.\n            <text>Are there no legal and administrative restrictions on the functioning of LGBTI organisations or publications?</text>'
# Format message with the command-r chat template
messages = [{"role": "user", "content": msg}]
inputs = tokenizer.apply_chat_template(
    messages,
    tokenize=True,
    add_generation_prompt=True,
    return_tensors="pt"
)

gen_tokens = model.generate(
    **inputs,   
    max_new_tokens=500,
    do_sample=True
)

gen_text = tokenizer.decode(gen_tokens[0])
print(extract_model_answer(gen_text))
# Out:
# Loading weights: 100%|██████████| 322/322 [00:00<00:00, 3085.15it/s]
# A jeni bindur në rregullime legale ose administrative që ndahërohen funksionimit të organizata ose publikimateve LGBTI?

# %%
import deepl
import os

deepl_client = deepl.DeepLClient(os.getenv('DEEPL_API_KEY'))

result = deepl_client.translate_text("no", target_lang="SQ", source_lang="EN")
print(result.text)
# Out:
# jo
